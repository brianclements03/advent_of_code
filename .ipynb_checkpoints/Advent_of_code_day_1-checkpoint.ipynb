# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Part 1
# Count the number of times a depth measurement increases from the previous measurement. (There is no measurement before the first measurement.)

# %%
depth = pd.read_csv('Advent_day1_data.csv')
depth = depth.drop(columns=['Unnamed: 0', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
       'Unnamed: 5', 'Unnamed: 6'])
depth = depth.rename(columns = {'Unnamed: 1':'depth_diff'})
depth
# Out:
#       depth_diff
# 0            149
# 1            163
# 2            165
# 3            160
# 4            179
# ...          ...
# 1995        8887
# 1996        8888
# 1997        8893
# 1998        8894
# 1999        8895
#
# [2000 rows x 1 columns]

# %%
depth.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %%
rows = list(depth.depth_diff)
rows
# Out:
# [149,
#  163,
#  165,
#  160,
#  179,
#  184,
#  186,
#  199,
#  207,
#  210,
#  211,
#  212,
#  228,
#  241,
#  242,
#  265,
#  269,
#  271,
#  287,
#  286,
#  295,
#  296,
#  293,
#  300,
#  301,
#  302,
#  304,
#  308,
#  320,
#  322,
#  321,
#  333,
#  350,
#  345,
#  348,
#  347,
#  351,
#  348,
#  349,
#  345,
#  353,
#  366,
#  376,
#  384,
#  387,
#  390,
#  391,
#  378,
#  382,
#  394,
#  409,
#  411,
#  415,
#  419,
#  424,
#  425,
#  427,
#  428,
#  436,
#  445,
#  446,
#  459,
#  464,
#  478,
#  479,
#  493,
#  492,
#  493,
#  482,
#  484,
#  491,
#  492,
#  497,
#  501,
#  506,
#  509,
#  521,
#  526,
#  527,
#  539,
#  546,
#  547,
#  551,
#  562,
#  567,
#  568,
#  573,
#  590,
#  591,
#  596,
#  612,
#  613,
#  618,
#  620,
#  593,
#  594,
#  596,
#  597,
#  596,
#  612,
#  616,
#  618,
#  620,
#  621,
#  622,
#  611,
#  612,
#  613,
#  610,
#  615,
#  616,
#  634,
#  647,
#  654,
#  655,
#  656,
#  657,
#  659,
#  676,
#  678,
#  675,
#  703,
#  715,
#  722,
#  738,
# ...

# %%
rows[1]
# Out:
# 163

# %%
# i = 0
# count = 0
# for i, n in enumerate(rows[:-1]):
#     if n > rows[i+1] > n:
#         count += 1
# #     i + 1
    
#     print(count)

# %%
# mylist = [1, 2, 2, 4, 2, 3]
# for i, j in enumerate(mylist[:-1]):
#     if j  == mylist[i+1]: 
#         mylist[i] = "foo" 
#         mylist[i+1] = "foo"
# print mylist
# [1, 'foo', 'foo', 4, 2, 3]

# %%
depth.depth_diff.diff()

# think boolean mask, where any negative number is true, then summing them
# Out:
# 0        NaN
# 1       14.0
# 2        2.0
# 3       -5.0
# 4       19.0
#         ...
# 1995     1.0
# 1996     1.0
# 1997     5.0
# 1998     1.0
# 1999     1.0
# Name: depth_diff, Length: 2000, dtype: float64

# %%
depth.index[1]
# Out:
# 1

# %%
depth[depth.depth_diff.diff()==True]
# Out:
#       depth_diff
# 10           211
# 11           212
# 14           242
# 21           296
# 24           301
# ...          ...
# 1992        8892
# 1995        8887
# 1996        8888
# 1998        8894
# 1999        8895
#
# [406 rows x 1 columns]

# %%
depth.diff()
# Out:
#       depth_diff
# 0            NaN
# 1           14.0
# 2            2.0
# 3           -5.0
# 4           19.0
# ...          ...
# 1995         1.0
# 1996         1.0
# 1997         5.0
# 1998         1.0
# 1999         1.0
#
# [2000 rows x 1 columns]

# %%
output = []
for i, row in depth.iterrows():
    if i > 0 :
        if depth.iloc[i]['depth_diff'] > depth.iloc[i-1]['depth_diff']:
            output.append(1)
        else:
            continue #output.append(np.nan). you didn't even need to append NaNs and then drop : )
# output

# %%
output = pd.Series(output)
output
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1611    1
# 1612    1
# 1613    1
# 1614    1
# 1615    1
# Length: 1616, dtype: int64

# %%
len(output)
# Out:
# 1616

# %% [markdown]
# # Part 2
# Your goal now is to count the number of times the sum of measurements in this sliding window increases from the previous sum. So, compare A with B, then compare B with C, then C with D, and so on. Stop when there aren't enough measurements left to create a new three-measurement sum.

# %%
# 199  A      
# 200  A B    
# 208  A B C  
# 210    B C D
# 200  E   C D
# 207  E F   D
# 240  E F G  
# 269    F G H
# 260      G H
# 263        H

# %%
output2 = []
for i, row in depth.iterrows():
    if i > 0 :
        if i < (len(depth)-2):
            if ((depth.iloc[i]['depth_diff'] + depth.iloc[i+1]['depth_diff'] 
                + depth.iloc[i+2]['depth_diff']) > (depth.iloc[i-1]['depth_diff'] 
                + depth.iloc[i]['depth_diff'] + depth.iloc[i+1]['depth_diff'])):
                    output2.append(1)
            else:
                continue

# %%
len(output2)
# Out:
# 1645
